# %%
# %%capture
# !pip install librosa spleeter ffmpeg-python

# %%
# %%capture
# !pip uninstall ffmpeg-python
# !pip install ffmpeg-python
# Out:
# Found existing installation: ffmpeg-python 0.2.0
# Uninstalling ffmpeg-python-0.2.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/ffmpeg/*
#     /usr/local/lib/python3.7/dist-packages/ffmpeg_python-0.2.0.dist-info/*
# Proceed (y/n)? y
#   Successfully uninstalled ffmpeg-python-0.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time
import pandas as pd
import os

# %% [markdown]
# ## Use Spleeter to isolate instruments audio file.

# %%
import spleeter
from IPython.display import Audio, display
from IPython.display import HTML
import IPython.display as ipd
import sys
# Out:
# 0.8.0

# %%
# !for f in /content/drive/MyDrive/DataMan_Songs/4_AudioWav/Audio1*.wav; do spleeter separate -o /content/drive/MyDrive/DataMan_Songs/Instruments -p spleeter:5stems-16kHz $f; done
# Out:
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Acceptance_So_Contagious/vocals.wav written succesfully
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Acceptance_So_Contagious/piano.wav written succesfully
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Acceptance_So_Contagious/drums.wav written succesfully
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Acceptance_So_Contagious/bass.wav written succesfully
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Acceptance_So_Contagious/other.wav written succesfully
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Akira_Yamaoka_Alone_In_The_Town/vocals.wav written succesfully
# INFO:spleeter:File /content/drive/MyDrive/DataMan_Songs/Instruments/Akira_Yamaoka_Alone_In_The_Town/piano.wav written succesfully
# ...

# %%
# !for f in /content/drive/MyDrive/DataMan_Songs/4_AudioWav/Audio2*.wav; do spleeter separate -o /content/drive/MyDrive/DataMan_Songs/Instruments -p spleeter:5stems-16kHz $f; done

# %%
# !for f in /content/drive/MyDrive/DataMan_Songs/4_AudioWav/Audio3*.wav; do spleeter separate -o /content/drive/MyDrive/DataMan_Songs/Instruments -p spleeter:5stems-16kHz $f; done

# %%
# !for f in /content/drive/MyDrive/DataMan_Songs/4_AudioWav/Audio4*.wav; do spleeter separate -o /content/drive/MyDrive/DataMan_Songs/Instruments -p spleeter:5stems-16kHz $f; done
